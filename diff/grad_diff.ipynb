# %%
import torch

path_single = "/home/jian/gaussian-splatting/debug/single_base_grad.pt"
path_fcgb   = "/home/jian/gaussian-splatting/debug/fcgb_pro.pt"

grad_single = torch.load(path_single)   # [N,3]
grad_fcgb   = torch.load(path_fcgb)     # [N,3]

print("single:", grad_single.shape, grad_single.dtype)
print("fcgb  :", grad_fcgb.shape, grad_fcgb.dtype)
# Out:
# single: torch.Size([507310, 3]) torch.float32
# fcgb  : torch.Size([4741800, 3]) torch.float32
