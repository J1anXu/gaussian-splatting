# %%
from plyfile import PlyData
import numpy as np

path = "/home/jian/gaussian-splatting/output/mip360/bicycle/point_cloud/fcgb_pro/iteration_500/point_cloud.ply"

ply = PlyData.read(path)

print("=== PLY ELEMENTS ===")
for elem in ply.elements:
    print(f"\nElement name: {elem.name}")
    print(f"Count: {elem.count}")

    print("Properties:")
    for p in elem.properties:
        print(f"  - {p.name}: {p.dtype}")

    # 打印前 5 条数据
    data = elem.data
    print("First 5 entries:")
    for i in range(min(5, elem.count)):
        print(data[i])
# Out:
# === PLY ELEMENTS ===
#
# Element name: vertex
# Count: 54275
# Properties:
#   - x: <bound method PlyProperty.dtype of PlyProperty('x', 'float')>
#   - y: <bound method PlyProperty.dtype of PlyProperty('y', 'float')>
#   - z: <bound method PlyProperty.dtype of PlyProperty('z', 'float')>
#   - nx: <bound method PlyProperty.dtype of PlyProperty('nx', 'float')>
#   - ny: <bound method PlyProperty.dtype of PlyProperty('ny', 'float')>
#   - nz: <bound method PlyProperty.dtype of PlyProperty('nz', 'float')>
#   - f_dc_0: <bound method PlyProperty.dtype of PlyProperty('f_dc_0', 'float')>
#   - f_dc_1: <bound method PlyProperty.dtype of PlyProperty('f_dc_1', 'float')>
#   - f_dc_2: <bound method PlyProperty.dtype of PlyProperty('f_dc_2', 'float')>
#   - f_rest_0: <bound method PlyProperty.dtype of PlyProperty('f_rest_0', 'float')>
#   - f_rest_1: <bound method PlyProperty.dtype of PlyProperty('f_rest_1', 'float')>
# ...
